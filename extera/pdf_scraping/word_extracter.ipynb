# %%
import pandas as pd
import tabula
import PyPDF2
import pandas as pd
import numpy as np
import re

file_path = './pdf_files/a1_skript_gr.pdf'

# %%
df = tabula.read_pdf(file_path, lattice=True, pages='all', )

# %%
words= ''
df = pd.DataFrame(df)
for index, row in df.iterrows():
    print(row.values[0])
    words += str(row.values[0])
# Out:
#   Unnamed: 0
# 0         A1
# 1        NaN
#                 www.deutschkurse-passau.d        Unnamed: 0  Unnamed: 1
# 0  link: Deutsch - Aber Hallo / Grundstuf               NaN         NaN
# 1                                     ISB  978-3-7098-0827-         NaN
# Empty DataFrame
# Columns: [GrammatikA1]
# Index: []
# Empty DataFrame
# Columns: [GrammatikA1]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#    Unnamed: 0
# 0         NaN
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []
#    Unnamed: 0  Unnamed: 1
# 0         NaN         NaN
# Empty DataFrame
# Columns: [Unnamed: 0]
# ...

# %%
words =  re.sub('\W+',r' ', words)
words.replace('NaN',' ')
# Out:
# 'Unnamed00A11 wwwdeutschkursepassaudUnnamed0Unnamed10linkDeutschAberHalloGrundstuf  1ISB978370980827 EmptyDataFrameColumnsGrammatikA1IndexEmptyDataFrameColumnsGrammatikA1IndexEmptyDataFrameColumnsUnnamed0IndexUnnamed0Unnamed1Unnamed2Unnamed3Unnamed4Unnamed50      1      2      3      Unnamed00 EmptyDataFrameColumnsUnnamed0IndexUnnamed0Unnamed10  EmptyDataFrameColumnsUnnamed0IndexUnnamed0Unnamed1Unnamed2Unnamed3Unnamed40     1     EmptyDataFrameColumnsUnnamed0Unnamed1IndexEmptyDataFrameColumnsschreibenIndexUnnamed0Unnamed1Unnamed2Unnamed3Unnamed40     Unnamed0Unnamed1e0 st 1 t 2 t 3 en 4 t 5 en ... 6IcheinePause7eIhrinBerlinUnnamed00 1 2irnachHause3heoEva4uDeutsch5iEvaeinEis6 ...  1 HatemkommausKairoUndduIchkomm2 IchtrinkKaffeeUndduIchtrinkW3 MariawohninRomUndduIchwohnin4 WirfragFrauLehmannUndduIchfrag5 PaulstudierinMnchenUndduIchstudie6 IchgehnachHauseUndduIchgehauEmptyDataFrameColumnsarbeitenIndexUnnamed00 1 Unnamed00 1 EmptyDataFrameColumnsUnnamed0IndexEmptyDataFrameColumnsUnnamed0
# ...
